# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('spinny_data.csv')

# %%
df2 = pd.read_csv('cardekho_data_1.csv')

# %%
df3 = pd.read_csv('cardekho_data2.csv')

# %%
df1.head()
# Out:
#   region   price   manufacturer      model  cylinders    fuel  odometer  \
# 0   agra  512000           tata      tiago        3.0  petrol     20979
# 1   agra  745000  maruti suzuki     baleno        4.0  petrol     20176
# 2   agra  465000        hyundai  grand i10        3.0     cng     41448
# 3   agra  546000  maruti suzuki    celerio        3.0  petrol      8527
# 4   agra  428000        hyundai     santro        4.0     cng    102049
#
#   transmission drive       type  seats  engine_cc  max_power  age
# 0       manual   fwd  hatchback    NaN        NaN        NaN    5
# 1       manual   fwd  hatchback    NaN        NaN        NaN    3
# 2       manual   fwd  hatchback    NaN        NaN        NaN    7
# 3       manual   fwd  hatchback    NaN        NaN        NaN    3
# 4       manual   fwd  hatchback    NaN        NaN        NaN    5

# %%
df = pd.concat([df1, df2])

# %%
6075 + 15216
# Out:
# 21291

# %%
df.shape
# Out:
# (21291, 14)

# %%
df = pd.concat([df, df3])

# %%
37814 + 21291
# Out:
# 59105

# %%
df.shape
# Out:
# (59105, 14)

# %%
df.sample(20)
# Out:
#           region      price manufacturer        model  cylinders      fuel  \
# 8395         NaN   350000.0      hyundai          i20        NaN    petrol
# 9502         NaN   625000.0       maruti    dzire vxi        NaN    petrol
# 5580        pune   247000.0      hyundai          i10        4.0    petrol
# 3832      jaipur   449000.0         ford         figo        3.0    petrol
# 1195      mumbai   695000.0         tata     tigor ev        NaN  electric
# 24099  bangalore   300000.0       maruti        swift        4.0    petrol
# 4359         NaN   695000.0       maruti        swift        NaN    diesel
# 6352         NaN   185000.0       maruti         alto        NaN    petrol
# 35478  ghaziabad   235000.0        honda       accord        4.0    petrol
# 29269       pune   850000.0        honda         city        4.0    petrol
# 37348       pune   750000.0      hyundai        venue        4.0    petrol
# ...

# %%
df.to_csv('cars_data.csv', index = False)
