# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cars_data_cleaned_1.csv')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#   region   price   manufacturer      model  cylinders    fuel  odometer  \
# 0   agra  512000           tata      tiago        3.0  petrol     20979
# 1   agra  745000  maruti suzuki     baleno        4.0  petrol     20176
# 2   agra  465000        hyundai  grand i10        3.0     cng     41448
# 3   agra  546000  maruti suzuki    celerio        3.0  petrol      8527
# 4   agra  428000        hyundai     santro        4.0     cng    102049
#
#   transmission drive       type  seats  engine_cc  max_power  age
# 0       manual   fwd  hatchback    NaN        NaN        NaN    5
# 1       manual   fwd  hatchback    NaN        NaN        NaN    3
# 2       manual   fwd  hatchback    NaN        NaN        NaN    7
# 3       manual   fwd  hatchback    NaN        NaN        NaN    3
# 4       manual   fwd  hatchback    NaN        NaN        NaN    5

# %%
df.shape
# Out:
# (57765, 14)

# %%
df['model'] = df['model'].replace('grand', 'grand i10')

# %%
df.isnull().sum()
# Out:
# region          15063
# price               0
# manufacturer        0
# model               0
# cylinders       15293
# fuel                0
# odometer            0
# transmission        0
# drive           19582
# type            15081
# seats            6091
# engine_cc        6120
# max_power        6258
# age                 0
# dtype: int64

# %%
df['region'] = df.groupby(['manufacturer', 'model'])['region']\
                 .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))
                #  \ --> it means that code is in continuation
# Out:
# /tmp/ipykernel_2905/4174064319.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))

# %%
df['region'].isnull().sum()
# Out:
# np.int64(713)

# %%
df['region'] = df.groupby(['manufacturer'])['region']\
                 .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# region              0
# price               0
# manufacturer        0
# model               0
# cylinders       15293
# fuel                0
# odometer            0
# transmission        0
# drive           19582
# type            15081
# seats            6091
# engine_cc        6120
# max_power        6258
# age                 0
# dtype: int64

# %%
df['cylinders'] = df.groupby(['manufacturer', 'model', 'fuel', 'transmission'])['cylinders']\
                 .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# region              0
# price               0
# manufacturer        0
# model               0
# cylinders         941
# fuel                0
# odometer            0
# transmission        0
# drive           19582
# type            15081
# seats            6091
# engine_cc        6120
# max_power        6258
# age                 0
# dtype: int64

# %%
df['cylinders'] = df.groupby(['manufacturer', 'model', 'fuel'])['cylinders']\
                 .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# region              0
# price               0
# manufacturer        0
# model               0
# cylinders         831
# fuel                0
# odometer            0
# transmission        0
# drive           19582
# type            15081
# seats            6091
# engine_cc        6120
# max_power        6258
# age                 0
# dtype: int64

# %%
df['cylinders'] = df.groupby(['manufacturer', 'model'])['cylinders']\
                 .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# region              0
# price               0
# manufacturer        0
# model               0
# cylinders         813
# fuel                0
# odometer            0
# transmission        0
# drive           19582
# type            15081
# seats            6091
# engine_cc        6120
# max_power        6258
# age                 0
# dtype: int64

# %%
df['cylinders'] = df.groupby(['manufacturer'])['cylinders']\
                 .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# region              0
# price               0
# manufacturer        0
# model               0
# cylinders           0
# fuel                0
# odometer            0
# transmission        0
# drive           19582
# type            15081
# seats            6091
# engine_cc        6120
# max_power        6258
# age                 0
# dtype: int64

# %%
df['drive'] = df.groupby(['manufacturer', 'model', 'fuel', 'transmission'])['drive']\
                 .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))
# Out:
# /tmp/ipykernel_2905/1576210882.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# region              0
# price               0
# manufacturer        0
# model               0
# cylinders           0
# fuel                0
# odometer            0
# transmission        0
# drive            1135
# type            15081
# seats            6091
# engine_cc        6120
# max_power        6258
# age                 0
# dtype: int64

# %%
df['cylinders'].value_counts()
# Out:
# cylinders
# 4.0     43822
# 3.0     13136
# 6.0       495
# 5.0       131
# 2.0        86
# 7.0        55
# 8.0        30
# 1.0         5
# 10.0        2
# 12.0        2
# 16.0        1
# Name: count, dtype: int64

# %%
df['drive'] = df.groupby(['manufacturer', 'model', 'fuel'])['drive']\
                 .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))
# Out:
# /tmp/ipykernel_2905/4222545681.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# region              0
# price               0
# manufacturer        0
# model               0
# cylinders           0
# fuel                0
# odometer            0
# transmission        0
# drive             991
# type            15081
# seats            6091
# engine_cc        6120
# max_power        6258
# age                 0
# dtype: int64

# %%
df['drive'] = df.groupby(['manufacturer', 'model'])['drive']\
                 .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))
# Out:
# /tmp/ipykernel_2905/3050005452.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# region              0
# price               0
# manufacturer        0
# model               0
# cylinders           0
# fuel                0
# odometer            0
# transmission        0
# drive             944
# type            15081
# seats            6091
# engine_cc        6120
# max_power        6258
# age                 0
# dtype: int64

# %%
df['drive'] = df.groupby(['manufacturer'])['drive']\
                 .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))
# Out:
# /tmp/ipykernel_2905/1284316986.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# region              0
# price               0
# manufacturer        0
# model               0
# cylinders           0
# fuel                0
# odometer            0
# transmission        0
# drive              13
# type            15081
# seats            6091
# engine_cc        6120
# max_power        6258
# age                 0
# dtype: int64

# %%
df[df['drive'].isnull()]
# Out:
#           region   price      manufacturer  model  cylinders    fuel  \
# 34042     nashik  200000  mahindra renault  logan        4.0  diesel
# 34043     nashik  199000  mahindra renault  logan        4.0  petrol
# 34044    chennai  145000  mahindra renault  logan        4.0  diesel
# 34045  paratwada  145000  mahindra renault  logan        4.0  diesel
# 34046       pune  119000  mahindra renault  logan        4.0  petrol
# 34047    lucknow  109000  mahindra renault  logan        4.0  diesel
# 34048     jaipur  150000  mahindra renault  logan        4.0  diesel
# 34049      thane  135000  mahindra renault  logan        4.0  petrol
# 34050       pune  200000  mahindra renault  logan        4.0  petrol
# 34051  bangalore  167000  mahindra renault  logan        4.0  petrol
# 34052  hyderabad  150000  mahindra renault  logan        4.0  petrol
# 34053      noida  100000  mahindra renault  logan        4.0  petrol
# 34054     jaipur  100000  mahindra renault  logan        4.0  diesel
#
# ...

# %%
df['drive'] = df['drive'].fillna('fwd')

# %%
df.isnull().sum()
# Out:
# region              0
# price               0
# manufacturer        0
# model               0
# cylinders           0
# fuel                0
# odometer            0
# transmission        0
# drive               0
# type            15081
# seats            6091
# engine_cc        6120
# max_power        6258
# age                 0
# dtype: int64

# %%
df['type'].sample(10)
# Out:
# 19274          NaN
# 21738    hatchback
# 3911     hatchback
# 3412     hatchback
# 48407    hatchback
# 7913           NaN
# 19523          NaN
# 52740        sedan
# 49187        sedan
# 21737     minivans
# Name: type, dtype: object

# %%
df['type'] = df.groupby(['manufacturer', 'model'])['type']\
                 .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))
# Out:
# /tmp/ipykernel_2905/4251093372.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# region             0
# price              0
# manufacturer       0
# model              0
# cylinders          0
# fuel               0
# odometer           0
# transmission       0
# drive              0
# type               2
# seats           6091
# engine_cc       6120
# max_power       6258
# age                0
# dtype: int64

# %%
df[df['type'].isnull()]
# Out:
#           region    price manufacturer        model  cylinders    fuel  \
# 14486  ghaziabad  4500000        lexus           nx        4.0  petrol
# 34077    jaunpur   300000       others  huracan evo       10.0  petrol
#
#        odometer transmission drive type  seats  engine_cc  max_power  age
# 14486     44000    automatic   fwd  NaN    5.0     2499.0     194.30    3
# 34077     80000    automatic   rwd  NaN    2.0     5204.0     602.11    5

# %%
df[df['manufacturer'] == 'lexus']
# Out:
#           region    price manufacturer model  cylinders    fuel  odometer  \
# 6707   ghaziabad  4100000        lexus    es        4.0  petrol     34000
# 14486  ghaziabad  4500000        lexus    nx        4.0  petrol     44000
# 15236  ghaziabad  4100000        lexus    es        4.0  petrol     33000
# 17927  ghaziabad  3990000        lexus    es        4.0  petrol     28000
# 34063  bangalore   185000        lexus    lx        8.0  diesel     60000
# 34064  ghaziabad  4293000        lexus    es        4.0  petrol     27760
#
#       transmission drive   type  seats  engine_cc  max_power  age
# 6707     automatic   fwd  sedan    5.0     2487.0     214.56    4
# 14486    automatic   fwd    NaN    5.0     2499.0     194.30    3
# 15236    automatic   fwd  sedan    5.0     2487.0     214.56    4
# 17927    automatic   fwd  sedan    5.0     2487.0     214.56    3
# 34063    automatic   4wd    suv    5.0     4461.0     261.00    8
# ...

# %%
df['model'] = df['model'].replace('vitara', 'vitara brezza').replace('rover', 'range rover')

# %%
df['model'] = df['model'].replace('3', '3 series').replace('5', '5 series').replace('7', '7 series')

# %%
df['model'] = df['model'].replace('kuv', 'kuv100')

# %%
df['model'] = df['model'].replace('6', '6 series')

# %%
df['model'] = df['model'].replace('dzire vxi', 'dzire').replace('dzire zxi', 'dzire').replace('dzire lxi', 'dzire')

# %%
df['model'] = df['model'].replace('xc', 'xc90').replace('xc 90', 'xc90')

# %%
df['model'] = df['model'].replace('cr', 'cr-v').replace('c', 'c-class').replace('eeco cargo', 'eeco').replace('mux', 'mu-x').replace('alturas', 'alturas g4')

# %%
df.loc[df['model'] == 'gtc4lusso', 'type'] = df.loc[df['model'] == 'gtc4lusso', 'type'].fillna('luxury vehicles')

# %%
df.loc[df['model'] == 'ghost', 'type'] = df.loc[df['model'] == 'ghost', 'type'].fillna('sedan')

# %%
# quattroporte
df.loc[df['model'] == 'quattroporte', 'type'] = df.loc[df['model'] == 'quattroporte', 'type'].fillna('sedan')

# %%
df.loc[df['model'] == 'cls', 'type'] = df.loc[df['model'] == 'cls', 'type'].fillna('sedan')

# %%
df.loc[df['model'] == 'rx', 'type'] = df.loc[df['model'] == 'rx', 'type'].fillna('crossover')

# %%
df['type'].value_counts()
# Out:
# type
# hatchback          23608
# sedan              15583
# suv                14121
# muv                 2981
# minivans             507
# crossover             95
# luxury vehicles       73
# pickup trucks         53
# convertibles          15
# coupe                 10
# wagon                  6
# hybrids                3
# mpv                    1
# Name: count, dtype: int64

# %%
df['type'] = df['type'].replace('mpv', 'muv')

# %%
df.shape
# Out:
# (57765, 14)

# %%
# df[df['type'].isnull()]
df = df.drop(index = [14486, 34077])

# %%
df.shape
# Out:
# (57763, 14)

# %%
df.isnull().sum()
# Out:
# region             0
# price              0
# manufacturer       0
# model              0
# cylinders          0
# fuel               0
# odometer           0
# transmission       0
# drive              0
# type             709
# seats           6091
# engine_cc       6120
# max_power       6258
# age                0
# dtype: int64

# %%
df[df['seats'] == 0]
# Out:
#             region  price   manufacturer   model  cylinders    fuel  odometer  \
# 9280          pune   1.15          honda    city        4.0  petrol     40000
# 18557    hyderabad  11.54         nissan   kicks        4.0  diesel     10000
# 23575    hyderabad   0.80  maruti suzuki    omni        3.0  petrol     70000
# 23587       bhopal   0.85  maruti suzuki    omni        3.0  petrol     60000
# 23593      kolkata   1.20  maruti suzuki    omni        3.0  petrol     70000
# 23607       rajkot   1.10  maruti suzuki    omni        3.0  petrol     60000
# 23622  jam jodhpur   0.75  maruti suzuki    omni        3.0  petrol    120000
# 23627     mandsaur   1.50  maruti suzuki    omni        3.0  petrol     90000
# 23632     jamnagar   0.70  maruti suzuki    omni        3.0  petrol    140000
# 23646     mandsaur   1.50  maruti suzuki    omni        3.0  petrol    120000
# 23649    gorakhpur   1.01  maruti suzuki    omni        3.0  petrol     70000
# ...

# %%
df['seats'] = df['seats'].replace(0.0, np.nan)

# %%
df['seats'].isnull().sum()
# Out:
# np.int64(6098)

# %%
df['seats'] = df.groupby(['manufacturer', 'model'])['seats']\
                 .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# region             0
# price              0
# manufacturer       0
# model              0
# cylinders          0
# fuel               0
# odometer           0
# transmission       0
# drive              0
# type               0
# seats              0
# engine_cc       6120
# max_power       6258
# age                0
# dtype: int64

# %%
df[df['seats'].isnull()]
# Out:
#              region    price   manufacturer           model  cylinders  \
# 14             agra   946000        hyundai         new i20        4.0
# 20             agra   884000        hyundai         new i20        4.0
# 25        ahmedabad   487910       mahindra          tuv300        3.0
# 57           ambala  1029000  maruti suzuki      new ertiga        4.0
# 60           ambala   601000          skoda       rapid new        3.0
# ...             ...      ...            ...             ...        ...
# 5964           pune   423000       mahindra      kuv100 nxt        3.0
# 6000           pune   289000  maruti suzuki     wagon r 1.0        2.0
# 6044  visakhapatnam   527000        hyundai  new santro 1.1        4.0
# 6053  visakhapatnam   882000  maruti suzuki         s-cross        4.0
# 6054  visakhapatnam  1052323  maruti suzuki           jimny        4.0
#
#             fuel  odometer transmission drive       type  seats  engine_cc  \
# ...

# %%
df['model'] = df['model'].str.strip()

# %%
df[df['model'] == 'polo']
# Out:
#           region   price manufacturer model  cylinders    fuel  odometer  \
# 182    bangalore  460000   volkswagen  polo        3.0  petrol    124416
# 400    bangalore  542000   volkswagen  polo        3.0  petrol     74539
# 477    bangalore  590000   volkswagen  polo        3.0  petrol     71311
# 481    bangalore  480000   volkswagen  polo        3.0  petrol     50699
# 490    bangalore  388000   volkswagen  polo        3.0  petrol     68274
# ...          ...     ...          ...   ...        ...     ...       ...
# 41849   dehradun  550000   volkswagen  polo        3.0  petrol     48141
# 42174     rajkot  297000   volkswagen  polo        3.0  petrol    157151
# 42490      surat  477000   volkswagen  polo        3.0  petrol     75682
# 42736      surat  454000   volkswagen  polo        3.0  petrol     23677
# 43727     indore  375000   volkswagen  polo        3.0  diesel     62000
#
#       transmission drive       type  seats  engine_cc  max_power  age
# ...

# %%
df['model'] = df['model'].replace('tuv300', 'tuv 300').replace('new i20', 'i20').replace('new ertiga', 'ertiga').replace('kuv100 nxt', 'kuv100').replace('kuv 100', 'kuv100').replace('new rapid', 'rapid').replace('new santro 1.1', 'santro').replace('wagon r 1.0', 'wagon r')

# %%
df.loc[df['model'] == 's-cross', 'seats'] = df.loc[df['model'] == 's-cross', 'seats'].fillna(5)

# %%
df.loc[df['model'] == 'jimny', 'seats'] = df.loc[df['model'] == 'jimny', 'seats'].fillna(5)

# %%
df.loc[df['model'] == 'curvv', 'seats'] = df.loc[df['model'] == 'curvv', 'seats'].fillna(5)

# %%
df['model'] = df['model'].replace('rapid new', 'rapid').replace('figo aspire', 'figo').replace('xuv 300', 'xuv300')

# %%
df.loc[df['model'] == 'urban cruiser hyryder', 'seats'] = df.loc[df['model'] == 'urban cruiser hyryder', 'seats'].fillna(5)

# %%
df.loc[df['model'] == 'exter', 'seats'] = df.loc[df['model'] == 'exter', 'seats'].fillna(5)

# %%
df.loc[df['model'] == 'fronx', 'seats'] = df.loc[df['model'] == 'fronx', 'seats'].fillna(5)

# %%
df.loc[df['model'] == 'thar roxx', 'seats'] = df.loc[df['model'] == 'thar roxx', 'seats'].fillna(5)

# %%
df.loc[df['model'] == 'tiago jtp', 'seats'] = df.loc[df['model'] == 'tiago jtp', 'seats'].fillna(5)

# %%
df.loc[df['model'] == 'elevate', 'seats'] = df.loc[df['model'] == 'elevate', 'seats'].fillna(5)

# %%
df.loc[df['model'] == 'creta n-line', 'seats'] = df.loc[df['model'] == 'creta n-line', 'seats'].fillna(5)

# %%
df.loc[df['model'] == 'syros', 'seats'] = df.loc[df['model'] == 'syros', 'seats'].fillna(5)

# %%
df.loc[df['model'] == 'xuv 3xo', 'seats'] = df.loc[df['model'] == 'xuv 3xo', 'seats'].fillna(5)

# %%
df.loc[df['model'] == 'countryman', 'seats'] = df.loc[df['model'] == 'countryman', 'seats'].fillna(5)

# %%
df['model'] = df['model'].replace('wagon r 1.2', 'wagon r').replace('fluidic verna 4s', 'verna').replace('b-class', 'b class')

# %%
df['model'] = df['model'].replace('cross polo', 'polo')

# %%
df.loc[df['model'] == 'venue n-line', 'seats'] = df.loc[df['model'] == 'venue n-line', 'seats'].fillna(5)

# %%
df[df['engine_cc'].isnull()]
# Out:
#           region  price   manufacturer      model  cylinders    fuel  \
# 0           agra   5.12           tata      tiago        3.0  petrol
# 1           agra   7.45  maruti suzuki     baleno        4.0  petrol
# 2           agra   4.65        hyundai  grand i10        3.0     cng
# 3           agra   5.46  maruti suzuki    celerio        3.0  petrol
# 4           agra   4.28        hyundai     santro        4.0     cng
# ...          ...    ...            ...        ...        ...     ...
# 47411  bangalore   2.00          honda       city        4.0  petrol
# 50045     mumbai   7.80          honda       city        4.0  petrol
# 50046     mumbai   5.90          honda       city        4.0  petrol
# 50091     mumbai   1.25          honda       city        4.0  petrol
# 56032  new delhi   1.30          honda       city        4.0  petrol
#
#        odometer transmission drive       type  seats  engine_cc  max_power  \
# ...

# %%
df['engine_cc'] = df.groupby(['manufacturer','model'])['engine_cc']\
                   .transform(lambda x: x.fillna(x.median()))

# %%
# df['engine_cc'] = pd.to_numeric(df['engine_cc'], errors='coerce')

# %%
df['engine_cc'] = df['engine_cc'].fillna(df['engine_cc'].median())

# %%
df.isnull().sum()
# Out:
# region             0
# price              0
# manufacturer       0
# model              0
# cylinders          0
# fuel               0
# odometer           0
# transmission       0
# drive              0
# type               0
# seats              0
# engine_cc          0
# max_power       6258
# age                0
# dtype: int64

# %%
df['engine_cc'].sample(20)
# Out:
# 17182    1197.0
# 54651    1396.0
# 52836     998.0
# 48523     998.0
# 11619    1248.0
# 38904    1086.0
# 46806    1199.0
# 45886    1120.0
# 47743    1248.0
# 2694     1199.0
# 51719    1120.0
# 6934     1248.0
# 29081     936.0
# 987      1197.0
# 44775     998.0
# 33375    1368.0
# 26376    1198.0
# 6074     1197.0
# 48674     814.0
# 36559     998.0
# Name: engine_cc, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57763 entries, 0 to 57764
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   region        57763 non-null  object
#  1   price         57763 non-null  int64
#  2   manufacturer  57763 non-null  object
#  3   model         57763 non-null  object
#  4   cylinders     57763 non-null  float64
#  5   fuel          57763 non-null  object
#  6   odometer      57763 non-null  int64
#  7   transmission  57763 non-null  object
#  8   drive         57763 non-null  object
#  9   type          57763 non-null  object
#  10  seats         57763 non-null  float64
#  11  engine_cc     57763 non-null  float64
#  12  max_power     51505 non-null  float64
#  13  age           57763 non-null  int64
# dtypes: float64(4), int64(3), object(7)
# memory usage: 6.6+ MB

# %%
df['engine_cc'] = df['engine_cc'].astype('int')

# %%
df[df['max_power'].isnull()]
# Out:
#           region   price   manufacturer      model  cylinders    fuel  \
# 0           agra  512000           tata      tiago        3.0  petrol
# 1           agra  745000  maruti suzuki     baleno        4.0  petrol
# 2           agra  465000        hyundai  grand i10        3.0     cng
# 3           agra  546000  maruti suzuki    celerio        3.0  petrol
# 4           agra  428000        hyundai     santro        4.0     cng
# ...          ...     ...            ...        ...        ...     ...
# 54875  new delhi  125000          honda       cr-v        4.0  petrol
# 54889      noida  300000          honda       cr-v        4.0  petrol
# 54897  new delhi  130000          honda       city        4.0  petrol
# 56549       pune  105000  maruti suzuki     estilo        4.0  petrol
# 57028       pune  335000  maruti suzuki      swift        4.0  diesel
#
#        odometer transmission drive       type  seats  engine_cc  max_power  \
# ...

# %%
df['max_power'] = df.groupby('engine_cc')['max_power'].transform(
    lambda x: x.fillna(x.median())
)

# %%
df.isnull().sum()
# Out:
# region           0
# price            0
# manufacturer     0
# model            0
# cylinders        0
# fuel             0
# odometer         0
# transmission     0
# drive            0
# type             0
# seats            0
# engine_cc        0
# max_power       94
# age              0
# dtype: int64

# %%
df['max_power'] = df['max_power'].fillna(df['max_power'].median())

# %%
df.isnull().sum()
# Out:
# region          0
# price           0
# manufacturer    0
# model           0
# cylinders       0
# fuel            0
# odometer        0
# transmission    0
# drive           0
# type            0
# seats           0
# engine_cc       0
# max_power       0
# age             0
# dtype: int64

# %%
df.head()
# Out:
#   region   price   manufacturer      model  cylinders    fuel  odometer  \
# 0   agra  512000           tata      tiago        3.0  petrol     20979
# 1   agra  745000  maruti suzuki     baleno        4.0  petrol     20176
# 2   agra  465000        hyundai  grand i10        3.0     cng     41448
# 3   agra  546000  maruti suzuki    celerio        3.0  petrol      8527
# 4   agra  428000        hyundai     santro        4.0     cng    102049
#
#   transmission drive       type  seats  engine_cc  max_power  age
# 0       manual   fwd  hatchback    5.0       1199      84.88    5
# 1       manual   fwd  hatchback    5.0       1197      81.86    3
# 2       manual   fwd  hatchback    5.0       1197      81.86    7
# 3       manual   fwd  hatchback    5.0        998      67.04    3
# 4       manual   fwd  hatchback    5.0       1086      68.05    5

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv('cars_missing_value_imputed.csv', index = False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58914 entries, 0 to 58913
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   region        58914 non-null  object
#  1   price         58914 non-null  float64
#  2   manufacturer  58914 non-null  object
#  3   model         58914 non-null  object
#  4   cylinders     58914 non-null  float64
#  5   fuel          58914 non-null  object
#  6   odometer      58914 non-null  int64
#  7   transmission  58914 non-null  object
#  8   drive         58914 non-null  object
#  9   type          58914 non-null  object
#  10  seats         58914 non-null  float64
#  11  engine_cc     58914 non-null  int64
#  12  max_power     58914 non-null  float64
#  13  age           58914 non-null  int64
# dtypes: float64(4), int64(3), object(7)
# memory usage: 6.3+ MB
